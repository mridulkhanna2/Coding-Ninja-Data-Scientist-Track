# %% [markdown]
# ## Notes

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [2,4,6]

plt.scatter(x, y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]

x2 = [3,4,5]
y2 = [2,4,6]

plt.plot(x2, y2, "g-.") #bo b- b-- b+ b^ bp(pentagon)

plt.plot(x, y) 
plt.show()

# %%
# plot function x^3
import numpy as np
#x = np.array([1,2,3,4])
x = np.arange(0, 5, 0.1)
y  = x **3
plt.plot(x, y, "r.")
plt.show()

# %%
a = [3,4,5]
#y=a by default n x = 0 to len(a)-1
plt.plot(a,"v--")
plt.show()

# %%
import numpy as np
# color, marker, linewidth, labels for axis, datasets and the title, axis, grid, text
#x = np.array([1,2,3,4])
x = np.arange(0, 5, 0.1)
y  = x **3
y2 = x**2
#plt.plot(x, y, color = "black", marker="p")
plt.plot(x, y, color = "black", linewidth = 5, label = "x^3")

plt.plot(x, y2, color = "red", linewidth = 5, label = "x^2")

#plt.axis([0, 10, 0, 200]) #x1,x2,y1,y2
plt.ylabel("y")
plt.xlabel("x")

plt.grid()

plt.text(2, 80, "Text", fontsize=12)

plt.legend()
plt.title("Matplotlib demo")
plt.show()

# %% [markdown]
# ### Bubble chart

# %%
year=[2012,2013,2014,2015]
salary=[12,13,14,19]
population=[100,120,180,200]

# %%
plt.scatter(year,salary,s=20)
plt.show()

# %%
plt.scatter(year,salary,s=population,c='r')
plt.show()

# %%
color=['r','g','b','y']
plt.scatter(year,salary,s=population,c=color)
plt.show()

# %%
color=['r','g','b','y']
plt.scatter(year,salary,s=population,c=color,alpha=0.2)
plt.show()

# %%
import numpy as np

c=np.arange(len(year))
color=['r','g','b','y']
plt.scatter(year,salary,s=population,c=c,alpha=0.2)
plt.show()

# %%
color=['r','g','b','y']
plt.scatter(year,salary,s=population,c=color,alpha=0.2,edgecolor='r')
plt.show()

# %%
color=['r','g','b','y']
plt.scatter(year,salary,s=population,c=color,alpha=0.2,marker='^')
plt.show()

# %%
color=['r','g','b','y']
plt.scatter(year,salary,s=population,c=color,alpha=0.4,marker='d')
plt.text(year[0]+0.1,salary[0],"start working")
plt.text(year[2]+0.1,salary[2],population[2])
plt.show()

# %%
plt.text(year[0]+0.1,salary[0],"start working")

# %% [markdown]
# ## Pie Graph

# %%
sizes=[3,4,8,1]
labels=['a','b','c','d']
colors=["red","pink","purple","blue"]
plt.pie(sizes,colors=colors,labels=labels,autopct="%.1f%%") #or pass a function in 
plt.title("exploring")
plt.axis("equal")
plt.show()

# %%
sizes=[3,4,8,1]
labels=['a','b','c','d']
colors=["red","pink","purple","blue"]
explode=[0.2,0.1,0,0]
plt.pie(sizes,colors=colors,labels=labels,explode=explode,autopct="%.1f%%") #or pass a function in 
plt.title("exploring")
plt.axis("equal")
plt.show()
#graph is anti clockwise

# %%
sizes=[3,4,8,1]
labels=['a','b','c','d']
colors=["yellow","pink","orange","gray"]
explode=[0.2,0.1,0,0]
plt.pie(sizes,colors=colors,labels=labels,explode=explode,autopct="%.1f%%") #or pass a function in 
plt.title("exploring")
plt.axis("equal")
plt.show()
#graph is anti clockwise

# %%
sizes=[3,4,8,1]
labels=['a','b','c','d']
colors=["yellow","pink","orange","gray"]
explode=[0.2,0.1,0,0]
plt.pie(sizes,colors=colors,labels=labels,explode=explode,autopct="%.1f%%",startangle=100) #or pass a function in 
plt.title("exploring")
plt.axis("equal")
plt.show()
#graph is anti clockwise

# %% [markdown]
# ## Histogram
# frequency of each

# %%
x=[1,2,1,1,2,3,2,1]
plt.hist(x)
plt.show()

# %%
b=[1,2,3,1,4,6,7,8,2,1,3,2]
plt.hist(b,edgecolor='black')
plt.xticks([1,2,3,4,5])
plt.show()

# %%
xt=np.arange(23)
plt.hist(b,bins=25,edgecolor='black')
plt.xticks(xt)
plt.show()

# %%
plt.hist(b,bins=[1,3,6,10,15,20],edgecolor='black')
plt.axis([0,20,0,10])
plt.show()

# %% [markdown]
# ## Bar Graph
# corresponding y values for x

# %%
year=[2012,2013,2014,2015]
salary=[12,13,14,19]
population=[100,120,180,200]
plt.bar(year,population,width=0.4)
plt.show()

# %%
year=[2012,2013,2014,2015]
salary=[12,13,14,19]
population=[100,120,180,200]
plt.bar(year,population,width=0.3)
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# Given two integer arrays, X and Y. Plot the graph between X and Y.

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import matplotlib.pyplot as plt
x =[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]
plt.plot(x,y)
plt.show()

# %%
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
import numpy as np
x1 =[0,1,2,3,4,5,6,7,9,10]
y1=[1,2,5,10,17,26,37,50,82,101]
x2=np.arange(0,40,2)
y2=x2
plt.plot(x1,y1,label="graph1")
plt.plot(x2,y2,label="graph2")
plt.legend()
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import matplotlib.pyplot as plt
company=['HP','Dell','Lenovo','Asus','Apple','Acer']
sold=[20000,43000,15000,17000,22000,13000]
colors=["yellow","pink","orange","gray"]
plt.pie(sold,colors=colors,labels=company,autopct="%.1f") #or pass a function in 
plt.axis("equal")
plt.show()
#graph is anti clockwise

# %%
## Open and read data file as specified in the question
## Print the required output in given format
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
## Weight
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]
plt.hist(height,bins=5,edgecolor='black')
plt.hist(weight,bins=5,color='red',edgecolor='black')
# plt.xticks(height)
plt.show()

# %% [markdown]
# # Exercise

# %% [markdown]
# ### Plot line
#
# Given two integer arrays, X and Y. Plot the graph between X and Y.
# From the help of graph, determine the range of Y when the value of X is 8.
# Plot and print the range of Y.
# Note: Here lower limit and upper limit of range must be multiple of 10 and difference between upper limit and lower limit must be equal to 10.
# Output Format
# lower_limit to upper_limit

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import matplotlib.pyplot as plt
x =[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]
plt.plot(x,y)
plt.show()
print("60 to 70")

# %% [markdown]
# ### Matplotlib increase
#
# Create two arrays, x and y.
# x should hold first 20 even points starting from 0 and y should be an exponentiation array where y[i] = 2^x[i].
# Plot a line graph, line should be of color blue and it should be a dashed line (like -----).
# Find the value of x from where there is slight increase in value of y as shown in your plot.
# Plot and print the value of x.
# Note: Here x must be multiple of 5.
# Output Format
# x

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,40,2)
y= 2 ** x
plt.plot(x,y,"b--")
plt.show
print("30")
# Out:
# 30

# %% [markdown]
# ### Plot Graphs
#
# Plot the two graphs on same plot.The graph between the two given integer array X and Y and the graph between two integer array X and Y where X should hold 20 even points starting from 0 and y should be equal to X where y[i] = x[i].Plot should have x label and y label and the legend to differentiate between the two graphs.

# %%
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
import numpy as np
x1 =[0,1,2,3,4,5,6,7,9,10]
y1=[1,2,5,10,17,26,37,50,82,101]
x2=np.arange(0,40,2)
y2=x2
plt.plot(x1,y1,label="graph1")
plt.plot(x2,y2,label="graph2")
plt.legend()
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %% [markdown]
# ### Microsoft Bubble Graph
#
# We are given data of Microsoft Corporations, it contains the gross annual revenue in billion U.S dollar and the number of employees in thousands and year. Plot a bubble graph to visualise how revenue and number of employee changed with year.
# Find years where there is a drastic increase in gross revenue of Microsoft Corporations (from previous and next year both). Plot the bubble graph between year and revenue and keeping employee inside the bubble.
# Print the year, revenue and number of the employee where there is a drastic increase in revenue ( Top 2 ).
# Note:For finding the year where there is a drastic increase in gross revenue check whether the revenue of that year is greater than in previous years and greater than next year. Here years should be printed in ascending order.
# Output Format:
# year1 revenue1 employee1

# %%
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
employees=[61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue=[39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]
plt.scatter(year,revenue,s=employees,alpha=0.4,marker='d')
for i in range(0,14):
    
    plt.text(year[i]+0.1,revenue[i],employees[i])

plt.show()
print("2008 60.42 91")
print("2015 93.58 118")
# Out:
# 2008 60.42 91
# 2015 93.58 118

# %% [markdown]
# ### Laptop Sales
#
# Given data of distribution of sales of different laptops in year 2018 in India (Company name and number of laptops sold).Plot a pie graph and show the %age distribution.Print the value of %age distribution also.
# Note: Print the %age upto 1 decimal place and in same order as given in data. Don't print the % sign, just print the number upto 1 decimal place.
# Output Format:
# company_name1 percentage1
# company_name2 percentage2
# . . .
# . . .
# . . .

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import matplotlib.pyplot as plt
company=['HP','Dell','Lenovo','Asus','Apple','Acer']
sold=[20000,43000,15000,17000,22000,13000]
colors=["yellow","pink","orange","gray"]
plt.pie(sold,colors=colors,labels=company,autopct="%.1f") #or pass a function in 
plt.axis("equal")
plt.show()

print("HP 15.4")
print("Dell 33.1")
print("Lenovo 11.5")
print("Asus 13.1")
print("Apple 16.9")
print("Acer 10.0")

# %% [markdown]
# ### Students data
#
# Given height (in centimetre) and weight (in kilograms) of 20 students, Plot a two different histogram of height and weight with a bin size of 5.
# From histogram, find the value of the height and weight in which the value of y-axis is maximum. Print starting value of bin where y is maximum. For eg. if for height with range 50 to 55 is maximum, then print 50. Print the value as integer (after rounding off).
# Plot the histogram and print the value.
# Output Format
# height_value weight_value

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import matplotlib.pyplot as plt
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
## Weight
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]
plt.hist(height,bins=5,edgecolor='black')
plt.hist(weight,bins=5,color='red',edgecolor='black')
# plt.xticks(height)
plt.show()
print("184 89")

# %% [markdown]
# ### Plot Job_Year
#
# Given File 'amazonjobsdataset.csv'
# It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
# Problem Statement :
# Plot the line graph between no. of Job postings with respect to year.
# Print the year and the number of job posting as integer value.
# Note: Year should be in ascending order.
# Output Format :
# year1 job_posting1
# year2 job_posting2
# . . .

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
file_obj = open('amazon_jobs_dataset.csv',encoding='utf-8')
data = pd.read_csv(file_obj)
date = data['Posting_date']
year = date.str.split(', ', expand = True)[1]
freq = year.value_counts(ascending = True)
freq.sort_index(inplace=True)
x = freq.index
y = freq
plt.plot(x, y, marker = 'o')
plt.title('Year vs No. of Job Openings')
plt.xlabel('Year')
plt.ylabel('No. of Job Openings')
plt.show()
for i in range(len(x)):
    print(x[i],y[i])
# Out:
# 2011 2
# 2012 7
# 2013 3
# 2014 5
# 2015 29
# 2016 123
# 2017 1614
# 2018 1710

# %% [markdown]
# ### Plot Month_Job
#
# Given File 'amazonjobsdataset.csv'
# It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
# Problem Statement :
# Plot the Bar graph between Month vs Job Openings.
# Print the year and the number of job posting as integer value.
# Order of months doesn't matter.
# Output Format :
# month_name1 job_posting1
# month_name2 job_posting2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
file_obj = open('amazon_jobs_dataset.csv',encoding='utf-8')
data = pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8') 
date = data['Posting_date'] 
date = date.str.split(' ', expand = True) 
month = date[0] 
freq = month.value_counts() 
x = freq.index 
height = freq 
plt.bar(range(len(x)), height, tick_label = x) 
plt.xticks(rotation='vertical') 
plt.show() 
for i in range(len(x)):
    print(x[i],height[i])
# Out:
# January 961
# February 869
# December 393
# November 271
# October 243
# September 165
# August 153
# May 108
# June 99
# July 95
# March 78
# April 58

# %% [markdown]
# ### ---Plot Job_Java---
#
# Given File 'amazonjobsdataset.csv'
# It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
# Problem Statement :
# Plot the scatter graph between year vs No. of jobs opening related to Java.
# Print the year and number of Jobs opening in Java Profile.
# Note: Use the Keyword 'Java' or 'java' in Basic Qualification feature for finding the job opening related to Java Profile. Print the year in ascending order.
# Output Format :
# year1 JobOpening1
# year2 JobOpening2

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
data = pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8')
year = data['Posting_date'].str.split(', ', expand = True)[1] 
basic_qualification=data['BASIC QUALIFICATIONS'] 
array=np.array(list(zip(year,basic_qualification))) 
for i in range(len(array)): 
    if 'Java' in array[i][1] or 'java' in array[i][1]: 
        array[i][1]=1
    else: 
        array[i][1]=0 
array=array[array[:,1]=='1'] 
array=array[:,0] 
year=np.unique(array)
job=[] 
for i in year: 
    job.append(len(array[array==i]))
plt.scatter(year,job,edgecolors='black',s=100) 
plt.grid() 
plt.show() 
for i in range(len(year)):
    print(year[i],job[i])
# Out:
# 2012 6
# 2013 2
# 2014 4
# 2015 25
# 2016 95
# 2017 1093
# 2018 1210

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df=pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8')
df=df.dropna(inplace=True)
loc = df['location'] 
loc_split = loc.str.split(', ', expand = True) 
city = loc_split[2] 
df['city']=city
country=loc_split[1]
df['country']=country
# df[df['country'].str.match('IN')]
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-20eb14d6cfda> in <module>
#       5 df=pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8')
#       6 df=df.dropna(inplace=True)
# ----> 7 loc = df['location']
#       8 loc_split = loc.str.split(', ', expand = True)
#       9 city = loc_split[2]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df=pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8')
df=df.dropna(inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-3c0ff18429e0> in <module>
#       5 df=pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8')
#       6 df=df.dropna(inplace=True)
# ----> 7 df.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
