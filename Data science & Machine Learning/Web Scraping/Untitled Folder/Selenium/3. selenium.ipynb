# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(executable_path = '/Users/codingninjastudio/Downloads/chromedriver')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="74aa36414930fae6985f6b3ec37ec802")>

# %%
driver.get('http://kanview.ks.gov/PayRates/PayRates_Agency.aspx')

# %%
a = driver.find_element_by_link_text('Adjutant General')
a
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="74aa36414930fae6985f6b3ec37ec802", element="0.1653784279162982-1")>

# %%
a.click()

# %%
from bs4 import BeautifulSoup
import pandas as pd

dataFrameList = []

for i in range(2) : 
    link = driver.find_element_by_id('MainContent_uxLevel2_JobTitles_uxJobTitleBtn_' + str(i))
    link.click()
    
    data = BeautifulSoup(driver.page_source, 'lxml')
    emp_table = data.table
    print(type(emp_table))
    df = pd.read_html(str(emp_table), header = 0)
    dataFrameList.append(df[0])
    driver.back()
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>

# %%
dataFrameList
# Out:
# [               Employee Name   Job Title Overtime Pay Total Gross Pay
#  0     Black,Shannon Michelle  Accountant        $0.00      $48,057.30
#  1             Bowser,Jamie M  Accountant        $0.00      $46,650.87
#  2           Bradford,Randy D  Accountant        $0.00      $42,707.40
#  3              Epps,David A.  Accountant        $0.00      $40,666.91
#  4         Fairbanks,Angela K  Accountant    $1,034.15      $45,614.43
#  5  Klenklen-Albertson,Tina L  Accountant        $0.00      $43,958.20
#  6            Nelson,Shayna I  Accountant        $0.00      $29,078.09,
#            Employee Name           Job Title Overtime Pay Total Gross Pay
#  0   Neth,Michael Edward  Accounting Manager      $239.40      $60,591.35
#  1  Rightmeier,Yolanda M  Accounting Manager    $1,324.44      $66,020.29]

# %%
# driver.find_element_by_id('MainContent_uxLevel2_JobTitles_uxJobTitleBtn_75')

# %%
a = driver.find_element_by_link_text('Board of Accountancy')
a.click()

# %%
from selenium.common.exceptions import NoSuchElementException

dataFrameList = []

i = 0
while True : 
    try : 
        link = driver.find_element_by_id('MainContent_uxLevel2_JobTitles_uxJobTitleBtn_' + str(i))
        link.click()

        data = BeautifulSoup(driver.page_source, 'lxml')
        emp_table = data.table
        print(type(emp_table))
        df = pd.read_html(str(emp_table), header = 0)
        dataFrameList.append(df[0])
        driver.back()
        i += 1
    except NoSuchElementException :
        break
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>

# %%
dataFrameList
# Out:
# [         Employee Name               Job Title Overtime Pay Total Gross Pay
#  0  Ramskill,Samantha S  Administrative Officer        $0.00      $41,545.21,
#      Employee Name                  Job Title Overtime Pay Total Gross Pay
#  0  Miller,Janet M  Administrative Specialist        $0.00       $9,628.95,
#          Employee Name                     Job Title Overtime Pay  \
#  0      Anderson,Ted C  Appt/elect Bd/comm Bd Member        $0.00
#  1        Helms,John R  Appt/elect Bd/comm Bd Member        $0.00
#  2     Lange,Corlene R  Appt/elect Bd/comm Bd Member        $0.00
#  3     Marsh,Michael L  Appt/elect Bd/comm Bd Member        $0.00
#  4  Mitchell,Kathryn J  Appt/elect Bd/comm Bd Member        $0.00
#  5   Richey,Meredith A  Appt/elect Bd/comm Bd Member        $0.00
#
#    Total Gross Pay
#  0         $280.00
#  1         $280.00
#  2         $280.00
#  3         $280.00
#  4         $245.00
#  5         $210.00  ,
# ...

# %%
df = pd.concat(dataFrameList, ignore_index = True)
# Out:
#          Employee Name                     Job Title Overtime Pay  \
# 0  Ramskill,Samantha S        Administrative Officer        $0.00
# 1       Miller,Janet M     Administrative Specialist        $0.00
# 2       Anderson,Ted C  Appt/elect Bd/comm Bd Member        $0.00
# 3         Helms,John R  Appt/elect Bd/comm Bd Member        $0.00
# 4      Lange,Corlene R  Appt/elect Bd/comm Bd Member        $0.00
# 5      Marsh,Michael L  Appt/elect Bd/comm Bd Member        $0.00
# 6   Mitchell,Kathryn J  Appt/elect Bd/comm Bd Member        $0.00
# 7    Richey,Meredith A  Appt/elect Bd/comm Bd Member        $0.00
# 8      Somers,Susan L.            Executive Director        $0.00
#
#   Total Gross Pay
# 0      $41,545.21
# 1       $9,628.95
# 2         $280.00
# 3         $280.00
# 4         $280.00
# 5         $280.00
# 6         $245.00
# 7         $210.00
# 8      $78,207.31

# %% [markdown]
# ## Use this link.
# ## Click on DS → Graph. Find and print name of all the problems which are listed under section “Topological Sorting”.

# %%
from selenium import webdriver
driver = webdriver.Chrome(executable_path = 'D:\Coding Ninja\Data science & Machine Learning\chromedriver')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="c88069da64e91e857b47ad031efb033f")>

# %%
driver.get('https://www.geeksforgeeks.org/')

# %%
ds=driver.find_element_by_link_text('Data Structures')

# %%
ds.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-44-6b65586fae85> in <module>
# ----> 1 ds.click()
#
# c:\users\mridu\appdata\local\programs\python\python38-32\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# c:\users\mridu\appdata\local\programs\python\python38-32\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
gr=driver.find_element_by_link_text('Graph')

# %%
gr.click()

# %%
ts=driver.find_element_by_class_name("topologicalSorting")

# %%
from bs4 import BeautifulSoup
import pandas as pd
link = driver.find_element_by_class_name("topologicalSorting")
data = BeautifulSoup(driver.page_source, 'lxml')
link.text
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-39-862d080e99b8> in <module>
#       1 from bs4 import BeautifulSoup
#       2 import pandas as pd
# ----> 3 link = driver.find_element_by_class_name("topologicalSorting")
#       4 data = BeautifulSoup(driver.page_source, 'lxml')
#       5 link.text
#
# c:\users\mridu\appdata\local\programs\python\python38-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\users\mridu\appdata\local\programs\python\python38-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
data
# Out:
# <html lang="en-US" prefix="og: http://ogp.me/ns#"><!--<![endif]--><head><script async="" src="https://cdn.jwplayer.com/libraries/AQP5aIG2.js" type="text/javascript"></script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <meta content="#0f9d58" name="theme-color"/>
# <meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="200" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# ...
