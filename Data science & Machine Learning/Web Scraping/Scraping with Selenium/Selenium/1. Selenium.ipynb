# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome(executable_path=r'chromedriver')

# %%
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="074a6e473991d82c828fb88e5268fd29")>

# %%
driver.get('https://www.codingninjas.com/')
#coding ninjas website opened

# %%
driver.title
# Out:
# 'Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas'

# %%
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot("test_shot.png")
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="en" style="--batchMonthBG:#FFEBC2; --batchCardBC:#FFEBC2; --batchMonthTC:#AC933C;"><head>\n    <meta charset="utf-8">\n    <title>Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas">\n    <meta property="og:title" content="Learn Coding Online with Live 1:1 Mentor Support | Coding Ninjas">\n    <meta name="description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:image" content="https://files.codingninjas.in/0000000000000723.jpg">\n
# ...

# %%
prac_btn=driver.find_element_by_link_text('Practice')

# %%
prac_btn.click()

# %%
driver.back()

# %%
prac_btn=driver.find_element_by_partial_link_text('Prac')

# %%
prac_btn.click()

# %%
prac_btn=driver.find_element_by_partial_link_text('acwr')
#error is link not available
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-36-50630266430d> in <module>
# ----> 1 prac_btn=driver.find_element_by_partial_link_text('acwr')
#
# c:\users\mridu\appdata\local\programs\python\python38-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_partial_link_text(self, link_text)
#     460             element = driver.find_element_by_partial_link_text('Sign')
#     461         """
# --> 462         return self.find_element(by=By.PARTIAL_LINK_TEXT, value=link_text)
#     463
#     464     def find_elements_by_partial_link_text(self, link_text):
#
# c:\users\mridu\appdata\local\programs\python\python38-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# ...

# %%
driver.maximize_window()

# %%
driver.refresh()

# %%
driver.get(driver.current_url) 
#refresh

# %%
driver.close()
driver.quit()

# %% [markdown]
# ### Locate element

# %%
driver.get("http://books.toscrape.com/")

# %%
c1=driver.find_element_by_link_text("Music")
#returns only 1st match

# %%
c1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="03edd7d4-947a-48c0-8c36-057a7beb67c7")>

# %%
c1.click()

# %%
book1=driver.find_element_by_partial_link_text("Kill")
#returns only 1st match

# %%
book1.click()

# %%
driver.back()

# %%
i1=driver.find_element_by_class_name("thumbnail")

# %%
i1.click()

# %%
li=driver.find_elements_by_class_name("thumbnail")

# %%
li
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="a0c9db25-ea41-4f53-938c-b6270ee61d7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="4d956cae-d7fe-4737-9163-c6c049a1d07e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="b9e87b39-237d-480e-810d-2837c47d90d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="9e8958b9-5870-4c46-b57a-eb5aec91cad5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="8f05cbde-a3d2-439f-830b-d79921647705")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="ad5f4269-1694-489b-a8d5-1bc2338b39f4")>,
# ...

# %%
ig=driver.find_elements_by_tag_name("img")
ig
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="a0c9db25-ea41-4f53-938c-b6270ee61d7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="4d956cae-d7fe-4737-9163-c6c049a1d07e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="b9e87b39-237d-480e-810d-2837c47d90d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="9e8958b9-5870-4c46-b57a-eb5aec91cad5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="8f05cbde-a3d2-439f-830b-d79921647705")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="ad5f4269-1694-489b-a8d5-1bc2338b39f4")>,
# ...

# %%
nm=driver.find_elements_by_name("viewport")
nm
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="0cb8309e-4211-490f-b791-47269e202177")>]

# %%
print(type(nm))
# Out:
# <class 'list'>

# %%
print(type(i1))
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>

# %%
pr=driver.find_element_by_class_name("price_color")

# %%
pr
pr.click()
#if element is not clickable then nothing will happen

# %%
pr.text
# Out:
# '£51.77'

# %%
pr.tag_name
# Out:
# 'p'

# %%
pr.get_attribute("class")
# Out:
# 'price_color'

# %%
pr.get_attribute("href")
#if att not present then None returned : no error

# %% [markdown]
# # Exercises

# %% [markdown]
# #### Click on Advanced Algorithms
#
# Open this website :
# Click on “Advanced algorithms”

# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome(executable_path='D:\Coding Ninja\Data science & Machine Learning/chromedriver')

# %%
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="abf3759af42ca77849b471e2982b5150")>

# %%
driver.get("https://codezen.codingninjas.com/dashboard?_ga=2.195026413.1358853661.1602860691-309529092.1602860691")

# %%
adv_btn=driver.find_element_by_partial_link_text('Advanced')

# %%
adv_btn.click()

# %% [markdown]
# #### Title of Google
#
# Open Google and Perform the following Steps :
# 1.Click on a link that has string “mage” present in it.
# 2.Find the title of the new page.
# 3.Go back to the previous page.

# %%
driver.get("https://www.google.com/")

# %%
imag_btn=driver.find_element_by_partial_link_text("mage")

# %%
imag_btn.click()

# %%
driver.title
# Out:
# 'Google Images'

# %%
driver.back()

# %% [markdown]
# ## Doubt
#
# ##### Find address
#
# From this Link :
# Find the element with <address> tag on the page

# %%
driver.get("https://www.codingninjas.com/courses?_ga=2.165113983.1358853661.1602860691-309529092.1602860691")

# %%
ad=driver.find_elements_by_class_name('links')

# %%
ad=driver.find_element_by_xpath("//div[contains(@class,'links')]/p/a")

# %%
ad.get_attribute("outerHTML")
# Out:
# '<a _ngcontent-serverapp-c128="" href="https://www.codingninjas.com/about" target="_blank" class="ng-star-inserted">About Us</a>'

# %%
ad.getAttribute("href")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-d48975256336> in <module>
# ----> 1 ad.getAttribute("href")
#
# AttributeError: 'WebElement' object has no attribute 'getAttribute'

# %% [markdown]
# ### Facebook sign up page

# %%
driver.get("https://www.facebook.com/r.php")

# %%
fn=driver.find_element_by_name("firstname")

# %%
fn.is_enabled()
# Out:
# True

# %%
day=driver.find_element_by_id("day")
day
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c70eab9de84117d6906b139d64e4154a", element="b04d04dd-65a0-48d1-9600-ef928dfd5065")>

# %%
day.click()

# %%
fm=driver.find_element_by_name("sex")

# %%
fm.is_selected()
# Out:
# True
