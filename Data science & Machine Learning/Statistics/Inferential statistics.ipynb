# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics

# %%
df=pd.read_csv('weight-height.csv')
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %% [markdown]
# # Sampling distribution:

# %%
df['Height'].mean() #population mean
# Out:
# 66.36755975482124

# %%
s=df['Height'].sample(n=50) # to extract samples by simple random sampling
s
# Out:
# 2408    68.464374
# 5858    64.601359
# 1525    71.052149
# 6255    60.797820
# 7751    66.706168
# 5550    60.807772
# 4937    72.983221
# 7616    64.456312
# 5885    63.790529
# 7571    67.757970
# 7069    61.424109
# 6389    64.347632
# 5732    56.078700
# 1244    69.080577
# 7262    57.072656
# 5723    68.258237
# 6172    65.182893
# 7784    61.622936
# 3638    66.822744
# 146     71.338376
# 8601    63.381808
# 4162    69.701668
# 7911    60.552017
# 6595    60.013864
# 1095    67.068304
# 1159    71.647580
# 844     71.527048
# 7190    63.535305
# 2661    62.182929
# 300     69.859588
# 9061    65.855639
# 6013    63.322851
# 6380    63.436831
# 6783    62.490958
# 5807    60.568484
# 6562    61.551367
# 4994    73.092871
# 3234    72.720603
# 8486    61.623103
# 2477    73.084894
# 6053    62.864633
# 401     65.313462
# 4117    65.808991
# 42      65.270346
# 2834    69.022974
# 2077    69.010642
# 8454    65.109614
# 1771    69.573260
# 9916    66.344055
# 6522    62.157751
# ...

# %%
s.mean() #sample mean
# Out:
# 65.6067994617751

# %%
sample_mean=[]
for i in range (1,1000):
    s=df['Height'].sample(n=50)
    sample_mean.append(s.mean())

# %%
sample_mean
# Out:
# [65.76673248800712,
#  66.10292489534774,
#  66.8721998571283,
#  66.16665191606597,
#  65.39258617701778,
#  65.64776645481244,
#  66.27197960981115,
#  65.71836143924457,
#  65.80076240741892,
#  67.6807531130123,
#  66.48408909810404,
#  65.86399732491375,
#  66.53620809829032,
#  66.24448572806227,
#  66.22798250095371,
#  66.61018464276087,
#  66.17967061308683,
#  66.66431378779116,
#  66.81860688647623,
#  66.13866605707081,
#  66.8029877006823,
#  66.64772598395864,
#  66.03325612925815,
#  66.9535079717683,
#  65.96267376995382,
#  65.81165591869271,
#  66.95212761089287,
#  67.07401081371825,
#  67.23768692309248,
#  66.81214320806532,
#  66.6483188138765,
#  67.25616129852943,
#  67.57704685195874,
#  66.14039953941943,
#  65.99234042505344,
#  66.04183797482168,
#  66.9863010887669,
#  66.1296047297009,
#  65.60072409492456,
#  66.79989598888857,
#  65.71454722453208,
#  67.36594567259927,
#  66.15054937602696,
#  66.93526710013339,
#  65.48857445649598,
# ...

# %%
plt.hist(sample_mean,bins=20)
plt.show()
#normal dist

# %% [markdown]
# #### Histogram for population:

# %%
plt.hist(df['Height'],bins=20)
plt.show()
#will not always be normal

# %%
plt.hist(df['Weight'],bins=20)
plt.show()
